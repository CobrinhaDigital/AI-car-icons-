# %% [markdown]
# <a href="https://colab.research.google.com/github/CobrinhaDigital/AI-car-icons-/blob/main/palavra_cruzada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/palavras.txt")
df
# Out:
#                  a
# 0                à
# 1            Aarão
# 2              aba
# 3          abacate
# 4       abacateiro
# ...            ...
# 261782    zurremos
# 261783      zurres
# 261784       zurro
# 261785      zurros
# 261786      zurrou
#
# [261787 rows x 1 columns]
